# %%
import numpy as np
import gvar as gv
import matplotlib.pyplot as plt

# %%
params2_11qubits = np.array([ 1.     ,  0.07462, -0.95714, -0.15878,  0.97046,  0.30464,
       -0.90114, -0.37882,  0.89032,  0.51624, -0.79014, -0.57164,
        0.76134,  0.7016 , -0.63662, -0.7381 ,  0.58938,  0.8472 ,
       -0.44508, -0.85664,  0.38566,  0.9446 , -0.2336 , -0.92412,
        0.1678 ,  0.9881 , -0.01164, -0.939  , -0.06578,  0.97838,
        0.22706, -0.90098, -0.27632,  0.91654,  0.4441 , -0.81176,
       -0.47754,  0.80438,  0.62802, -0.6759 , -0.6485 ,  0.64648,
        0.782  , -0.49634, -0.77884,  0.45826,  0.89222, -0.29146,
       -0.86078,  0.25688,  0.95262, -0.07414, -0.89208,  0.0329 ,
        0.96098,  0.14624, -0.87048, -0.18198,  0.91302,  0.35676,
       -0.8    , -0.37842,  0.82012,  0.54816, -0.68204, -0.54926,
        0.68686,  0.70586, -0.52226, -0.6881 ,  0.52118,  0.82392,
       -0.33888, -0.77762,  0.32564,  0.89736, -0.1313 , -0.82468,
        0.1235 ,  0.91778,  0.07038, -0.81762, -0.0849 ,  0.89544,
        0.27304, -0.76208, -0.2762 ,  0.81506,  0.46176, -0.66986,
       -0.44828,  0.70306,  0.62346, -0.52972, -0.57982,  0.5554 ,
        0.73664, -0.36216, -0.6787 ,  0.38118,  0.81796])
params1_11qubits = np.array([ 1.     ,  0.6194 , -0.21652, -0.85478, -0.7733 , -0.0597 ,
        0.73652,  0.98368,  0.48778, -0.35848, -0.89174, -0.67558,
        0.10442,  0.8363 ,  0.93998,  0.33916, -0.48934, -0.89532,
       -0.5556 ,  0.26348,  0.90686,  0.87024,  0.18756, -0.59972,
       -0.87208, -0.41602,  0.40764,  0.94932,  0.77874,  0.04016,
       -0.68582, -0.81962, -0.262  ,  0.54742,  0.96536,  0.66584,
       -0.11172, -0.7476 , -0.74756, -0.10766,  0.66126,  0.9503 ,
        0.54664, -0.2445 , -0.77582, -0.64616,  0.045  ,  0.74942,
        0.90746,  0.40538, -0.3611 , -0.7848 , -0.53012,  0.1957 ,
        0.8136 ,  0.84734,  0.27082, -0.45676, -0.7557 , -0.4033 ,
        0.3275 ,  0.85068,  0.7614 ,  0.13536, -0.5281 , -0.70592,
       -0.25926,  0.44634,  0.86456,  0.65658,  0.007  , -0.58652,
       -0.6355 , -0.12304,  0.54556,  0.84788,  0.55142, -0.11108,
       -0.60388, -0.54552,  0.01516,  0.62044,  0.80692,  0.43392,
       -0.20838, -0.60264, -0.43856,  0.1395 ,  0.67504,  0.75168,
        0.3146 , -0.28698, -0.57978, -0.33488,  0.25014,  0.6978 ,
        0.68222,  0.20112, -0.33602, -0.53224, -0.21988])
params2_15qubits = np.array([0.09868, 0.20994, 0.12756, 0.00462, 0.08922, 0.2073 , 0.14482,
       0.0114 , 0.05782, 0.19656, 0.16148, 0.02452, 0.04476, 0.18188,
       0.17932, 0.04728, 0.03114, 0.16554, 0.19074, 0.0606 ])
params1_15qubits = np.array([0.06104, 0.2091 , 0.30722, 0.29494, 0.1722 , 0.04604, 0.0072 ,
       0.10274, 0.2448 , 0.30612, 0.25326, 0.1168 , 0.02236, 0.03582,
       0.15288, 0.28066, 0.3105 , 0.22228, 0.08726, 0.00698])

p2_q11 = np.array([params2_11qubits, np.sqrt(1 - params2_11qubits) / np.sqrt(1e4)])
p2_q15 = np.array([params2_15qubits, np.sqrt(1 - params2_15qubits) / np.sqrt(1e4)])

# %%
plt.errorbar(np.linspace(0, 101, 101) * 6 / 20, params1_11qubits)
# Out:
# <ErrorbarContainer object of 3 artists>
