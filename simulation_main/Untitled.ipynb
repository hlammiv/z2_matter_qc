# %%
import numpy as np
import gvar as gv
import matplotlib.pyplot as plt

# %%
params1_7qubits = np.array([ 1.     ,  0.89802,  0.62734,  0.21294, -0.21776, -0.61088,
       -0.8588 , -0.92356, -0.78432, -0.47416, -0.0563 ,  0.38314,
        0.74208,  0.95962,  0.98414,  0.81202,  0.47104,  0.04438,
       -0.38626, -0.72478, -0.90486, -0.89128, -0.68546, -0.32216,
        0.11116,  0.52822,  0.84658,  0.98744,  0.93288,  0.69336,
        0.31244, -0.13018, -0.52786, -0.80986, -0.91918, -0.8269 ,
       -0.55546, -0.15608,  0.27436,  0.65694,  0.9144 ,  0.98194,
        0.85342,  0.54998,  0.14888, -0.28818, -0.64798, -0.86796,
       -0.90084, -0.7328 , -0.4095 ,  0.00632,  0.43014,  0.76952,
        0.9504 ,  0.94418,  0.74508,  0.40228, -0.0244 , -0.43598,
       -0.74028, -0.8923 , -0.84224, -0.6186 , -0.25256,  0.17464,
        0.56774,  0.8481 ,  0.95732,  0.87464,  0.61998,  0.2328 ,
       -0.1873 , -0.55494, -0.80614, -0.88108, -0.76058, -0.47748,
       -0.08488,  0.32384,  0.67876,  0.89296,  0.92942,  0.77862,
        0.46938,  0.06896, -0.33498, -0.65706, -0.83766, -0.83588,
       -0.65394, -0.32556,  0.0788 ,  0.4661 ,  0.76666,  0.90966,
        0.8728 ,  0.65556,  0.30982, -0.09134, -0.45854, -0.72596,
       -0.8364 , -0.76776, -0.5218 , -0.16568,  0.22832,  0.58466,
        0.8214 ,  0.89384,  0.78484,  0.52672,  0.15556, -0.22686,
       -0.56124, -0.7647 , -0.80104, -0.66262, -0.37692, -0.00474,
        0.37066,  0.67298,  0.84614,  0.846  ,  0.67918,  0.3768 ,
        0.0093 , -0.3583 , -0.63292, -0.7694 , -0.73756, -0.54182,
       -0.22552,  0.14092,  0.48706,  0.7355 ,  0.83648,  0.76852,
        0.55184,  0.22784, -0.1364 , -0.4572 , -0.67202, -0.74482,
       -0.64604, -0.40696, -0.07614,  0.27414,  0.5776 ,  0.76534,
        0.80006,  0.67882,  0.41838,  0.09078, -0.25108, -0.53132,
       -0.68628, -0.68738, -0.53644, -0.26244,  0.07404,  0.3924 ,
        0.6435 ,  0.76186,  0.7325 ,  0.56034,  0.28212, -0.0462 ,
       -0.3517 , -0.57166, -0.66504, -0.61022, -0.41104, -0.12606,
        0.18944,  0.48196,  0.67406,  0.72968,  0.64792,  0.43686,
        0.1378 , -0.16822, -0.43124, -0.59276, -0.61626, -0.50194,
       -0.27886,  0.01388,  0.3075 ,  0.54866,  0.67388,  0.6741 ,
        0.53864,  0.3104 ,  0.0134 , -0.26338, -0.4773 , -0.5742 ,
       -0.54136, -0.39166, -0.14286])


params2_11qubits = np.array([ 1.     ,  0.07462, -0.95714, -0.15878,  0.97046,  0.30464,
       -0.90114, -0.37882,  0.89032,  0.51624, -0.79014, -0.57164,
        0.76134,  0.7016 , -0.63662, -0.7381 ,  0.58938,  0.8472 ,
       -0.44508, -0.85664,  0.38566,  0.9446 , -0.2336 , -0.92412,
        0.1678 ,  0.9881 , -0.01164, -0.939  , -0.06578,  0.97838,
        0.22706, -0.90098, -0.27632,  0.91654,  0.4441 , -0.81176,
       -0.31462, -0.29506, -0.1853 , -0.0172 ,  0.17684,  0.35528,
        0.48408,  0.53094,  0.49076,  0.37858,  0.21642,  0.02876,
       -0.13272, -0.24774, -0.27908, -0.23086, -0.11254,  0.0565 ,
        0.22954,  0.3813 ,  0.47298,  0.50084,  0.44258,  0.31904,
        0.15594, -0.00154, -0.13954, -0.22038, -0.23012, -0.16276,
       -0.04382,  0.11158,  0.2621 ,  0.38328,  0.44458,  0.44336,
        0.37336,  0.25808,  0.1019 , -0.03194, -0.1341 , -0.17864,
       -0.16244, -0.09586,  0.02942,  0.17212,  0.29428,  0.38352,
        0.42396,  0.4016 ,  0.32444,  0.20056,  0.07578, -0.03522,
       -0.12076, -0.14384, -0.11672, -0.04108,  0.07186,  0.19516,
        0.29636,  0.36526,  0.389  ,  0.36114,  0.28346,  0.17068,
        0.06568, -0.028  , -0.08548, -0.09816, -0.06332,  0.00792,
        0.10398,  0.20312,  0.2864 ,  0.33316,  0.33784,  0.30618,
        0.23546,  0.14966,  0.05862, -0.01658, -0.05552, -0.05576,
       -0.01626,  0.04934,  0.1387 ,  0.21552,  0.28514,  0.31328,
        0.30842,  0.27976,  0.21324,  0.13332,  0.05784,  0.0087 ,
       -0.02084, -0.02552, -0.00168,  0.06676,  0.13   ,  0.1971 ,
        0.25626,  0.28608,  0.28582,  0.2594 ,  0.20772,  0.1447 ,
        0.09106,  0.03474,  0.0115 ,  0.00984,  0.0324 ,  0.07968,
        0.12516,  0.18652,  0.23254,  0.2534 ,  0.25854,  0.2418 ,
        0.1956 ,  0.14088,  0.10102])

params2_15qubits = np.array([0.09868, 0.20994, 0.12756, 0.00462, 0.08922, 0.2073 , 0.14482,
       0.0114 , 0.05782, 0.19656, 0.16148, 0.02452, 0.04476, 0.18188,
       0.17932, 0.04728, 0.03114, 0.16554, 0.19074, 0.0606 ])
params1_15qubits = np.array([0.06104, 0.2091 , 0.30722, 0.29494, 0.1722 , 0.04604, 0.0072 ,
       0.10274, 0.2448 , 0.30612, 0.25326, 0.1168 , 0.02236, 0.03582,
       0.15288, 0.28066, 0.3105 , 0.22228, 0.08726, 0.00698])

p2_q11 = np.array([params2_11qubits, np.sqrt(1 - params2_11qubits) / np.sqrt(1e4)])
p2_q15 = np.array([params2_15qubits, np.sqrt(1 - params2_15qubits) / np.sqrt(1e4)])

# %%
plt.plot(np.linspace(0, 201, 201) * 6 / 20, params1_11qubits, label=r'$\delta t = 0.3$')
plt.plot(np.linspace(0, 402, 402) * 3 / 20, params1_11qubits2, '--', label=r'$\delta t = 0.15$')
# plt.xlim(0, 30)
plt.xlabel('t')
plt.ylabel('C(t)')
plt.legend()
plt.savefig('correlatorailaisingeffects.pdf')

# %%
plt.plot(np.linspace(0, 2 * np.pi, 201) / 6 * 20, np.abs(np.fft.fft(params1_11qubits, norm='ortho')), label=r'$\delta t = 0.3$')
plt.plot(np.linspace(0, 2 * np.pi, 402) / 3 * 20, np.abs(np.fft.fft(params1_11qubits2, norm='ortho')), label=r'$\delta t = 0.15$')
plt.ylabel('fourier amplitude')
plt.xlabel('E')
# plt.xlim(0, 5)
plt.legend()
plt.savefig('fouriercomparison.pdf')

# %%
6 / 20 ==
# Out:
# True
